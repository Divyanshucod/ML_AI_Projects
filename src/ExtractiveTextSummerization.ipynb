kB)
# Installing collected packages: cymem, wasabi, spacy-loggers, spacy-legacy, shellingham, pydantic-core, murmurhash, marisa-trie, jinja2, cloudpathlib, catalogue, blis, annotated-types, srsly, pydantic, preshed, language-data, typer, langcodes, confection, weasel, thinc, spacy
# Successfully installed annotated-types-0.7.0 blis-1.1.0 catalogue-2.0.10 cloudpathlib-0.20.0 confection-0.1.5 cymem-2.0.10 jinja2-3.1.5 langcodes-3.5.0 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.11 preshed-3.0.9 pydantic-2.10.4 pydantic-core-2.27.2 shellingham-1.5.4 spacy-3.8.3 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.5.0 thinc-8.3.3 typer-0.15.1 wasabi-1.1.3 weasel-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install pytextrank
# Out:
# Collecting pytextrank
#   Downloading pytextrank-3.3.0-py3-none-any.whl.metadata (12 kB)
# Collecting GitPython>=3.1 (from pytextrank)
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting graphviz>=0.13 (from pytextrank)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting icecream>=2.1 (from pytextrank)
#   Downloading icecream-2.1.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting networkx>=2.6 (from networkx[default]>=2.6->pytextrank)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: pygments>=2.7.4 in c:\ml_ai_projects\venv\lib\site-packages (from pytextrank) (2.18.0)
# Requirement already satisfied: scipy>=1.7 in c:\ml_ai_projects\venv\lib\site-packages (from pytextrank) (1.13.1)
# Requirement already satisfied: spacy>=3.0 in c:\ml_ai_projects\venv\lib\site-packages (from pytextrank) (3.8.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython>=3.1->pytextrank)
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: colorama>=0.3.9 in c:\ml_ai_projects\venv\lib\site-packages (from icecream>=2.1->pytextrank) (0.4.6)
# Requirement already satisfied: executing>=0.3.1 in c:\ml_ai_projects\venv\lib\site-packages (from icecream>=2.1->pytextrank) (2.1.0)
# Requirement already satisfied: asttokens>=2.0.1 in c:\ml_ai_projects\venv\lib\site-packages (from icecream>=2.1->pytextrank) (3.0.0)
# Requirement already satisfied: numpy>=1.24 in c:\ml_ai_projects\venv\lib\site-packages (from networkx[default]>=2.6->pytextrank) (1.26.4)
# Requirement already satisfied: matplotlib>=3.7 in c:\ml_ai_projects\venv\lib\site-packages (from networkx[default]>=2.6->pytextrank) (3.10.0)
# Requirement already satisfied: pandas>=2.0 in c:\ml_ai_projects\venv\lib\site-packages (from networkx[default]>=2.6->pytextrank) (2.2.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.0.11)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (8.3.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.5.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (0.15.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (2.10.4)
# Requirement already satisfied: jinja2 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.1.5)
# Requirement already satisfied: setuptools in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (75.1.0)
# Requirement already satisfied: packaging>=20.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\ml_ai_projects\venv\lib\site-packages (from spacy>=3.0->pytextrank) (3.5.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython>=3.1->pytextrank)
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: language-data>=1.2 in c:\ml_ai_projects\venv\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy>=3.0->pytextrank) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\ml_ai_projects\venv\lib\site-packages (from matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\ml_ai_projects\venv\lib\site-packages (from pandas>=2.0->networkx[default]>=2.6->pytextrank) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\ml_ai_projects\venv\lib\site-packages (from pandas>=2.0->networkx[default]>=2.6->pytextrank) (2024.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\ml_ai_projects\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\ml_ai_projects\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\ml_ai_projects\venv\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\ml_ai_projects\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\ml_ai_projects\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\ml_ai_projects\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\ml_ai_projects\venv\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2024.12.14)
# Requirement already satisfied: blis<1.2.0,>=1.1.0 in c:\ml_ai_projects\venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3.0->pytextrank) (1.1.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\ml_ai_projects\venv\lib\site-packages (from thinc<8.4.0,>=8.3.0->spacy>=3.0->pytextrank) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in c:\ml_ai_projects\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\ml_ai_projects\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\ml_ai_projects\venv\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\ml_ai_projects\venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (0.20.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\ml_ai_projects\venv\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\ml_ai_projects\venv\lib\site-packages (from jinja2->spacy>=3.0->pytextrank) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\ml_ai_projects\venv\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy>=3.0->pytextrank) (1.2.1)
# Requirement already satisfied: six>=1.5 in c:\ml_ai_projects\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.7->networkx[default]>=2.6->pytextrank) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\ml_ai_projects\venv\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (3.0.0)
# Requirement already satisfied: wrapt in c:\ml_ai_projects\venv\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy>=3.0->pytextrank) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\ml_ai_projects\venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (0.1.2)
# Downloading pytextrank-3.3.0-py3-none-any.whl (26 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
# Downloading icecream-2.1.3-py2.py3-none-any.whl (8.4 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 364.6 kB/s eta 0:00:04
#    ------------ --------------------------- 0.5/1.7 MB 364.6 kB/s eta 0:00:04
#    ------------------ --------------------- 0.8/1.7 MB 466.0 kB/s eta 0:00:03
#    ------------------ --------------------- 0.8/1.7 MB 466.0 kB/s eta 0:00:03
#    ------------------------ --------------- 1.0/1.7 MB 540.9 kB/s eta 0:00:02
#    ------------------------ --------------- 1.0/1.7 MB 540.9 kB/s eta 0:00:02
#    ------------------------------ --------- 1.3/1.7 MB 583.5 kB/s eta 0:00:01
#    ------------------------------------ --- 1.6/1.7 MB 630.5 kB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 658.5 kB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, networkx, icecream, graphviz, gitdb, GitPython, pytextrank
# Successfully installed GitPython-3.1.44 gitdb-4.0.12 graphviz-0.20.3 icecream-2.1.3 networkx-3.4.2 pytextrank-3.3.0 smmap-5.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import spacy
import pytextrank
# Out:
# c:\ML_AI_Projects\venv\Lib\site-packages

# %%
nlp = spacy.load("en_core_web_lg")
nlp.add_pipe("textrank")

# %%
example = """
Deep learning (also known as deep structured learning) is part of a 
broader family of machine learning methods based on artificial neural networks with 
representation learning. Learning can be supervised, semi-supervised or unsupervised. 
Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, 
recurrent neural networks and convolutional neural networks have been applied to
fields including computer vision, speech recognition, natural language processing, 
machine translation, bioinformatics, drug design, medical image analysis, material
inspection and board game programs, where they have produced results comparable to 
and in some cases surpassing human expert performance. Artificial neural networks
(ANNs) were inspired by information processing and distributed communication nodes
in biological systems. ANNs have various differences from biological brains. Specifically, 
neural networks tend to be static and symbolic, while the biological brain of most living organisms
is dynamic (plastic) and analogue. The adjective "deep" in deep learning refers to the use of multiple
layers in the network. Early work showed that a linear perceptron cannot be a universal classifier, 
but that a network with a nonpolynomial activation function with one hidden layer of unbounded width can.
Deep learning is a modern variation which is concerned with an unbounded number of layers of bounded size, 
which permits practical application and optimized implementation, while retaining theoretical universality 
under mild conditions. In deep learning the layers are also permitted to be heterogeneous and to deviate widely 
from biologically informed connectionist models, for the sake of efficiency, trainability and understandability, 
whence the structured part.
"""

# %%
print('Original Document Size:',len(example))
doc = nlp(example)

for sent in doc._.textrank.summary(limit_phrases=2, limit_sentences=2):
    print(sent)
    print('Summary Length:',len(sent))
# Out:
# Original Document Size: 1822
# Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning,
# recurrent neural networks and convolutional neural networks have been applied to
# fields including computer vision, speech recognition, natural language processing,
# machine translation, bioinformatics, drug design, medical image analysis, material
# inspection and board game programs, where they have produced results comparable to
# and in some cases surpassing human expert performance.
# Summary Length: 81
# The adjective "deep" in deep learning refers to the use of multiple
# layers in the network.
# Summary Length: 20
